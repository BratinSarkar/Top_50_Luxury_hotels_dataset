# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 2: Load Dataset
file_path = 'Top_50_hotels_dataset.csv'  # Replace with your actual file path
df = pd.read_csv(file_path, encoding='latin-1') # or 'iso-8859-1' or 'cp1252'

# %%
# Step 3: Initial Exploration
print("Dataset Head:\n", df.head())
print("\nData Information:\n")
df.info()
print("\nDescriptive Statistics:\n", df.describe())
df.describe()
# Out:
# Dataset Head:
#     Rank                Name   Location  \
# 0     1     Capella Bangkok    Bangkok
# 1     2         Passalacqua  Lake Como
# 2     3  Rosewood Hong Kong  Hong Kong
# 3     4        Cheval Blanc      Paris
# 4     5     The Upper House  Hong Kong
#
#                                             Overview  Total_Rooms  \
# 0  A calming riverside oasis in the centre of cac...          101
# 1  A sumptuous Lake Como retreat made for enjoyin...           24
# 2     Masterful minimalism meets marble-lined luxury          413
# 3  Uber-stylish riverside luxury and world-class ...           72
# 4               A temple of Zen high above Hong Kong          117
#
#    Starting_Rate($)                               Dining_Area   Drinking_Area  \
# 0               600   Côte by Mauro Colagreco and Phra Nakhon          Stella
# 1              1300                        The Garden Terrace     Bar Terrace
# ...

# %%
# Distribution of starting rates
plt.figure(figsize=(8, 5))
# Assuming the correct column name is 'Starting_Rate($)'
sns.histplot(df['Starting_Rate($)'], kde=True, color='blue')
plt.title('Distribution of Starting Rates of Top Luxury Hotels')
plt.xlabel('Starting Rate ($)')
plt.ylabel('Frequency')
plt.show()

# %%
# Top 10 hotels by starting rate
# Assuming the correct column name is 'Starting_Rate($)' based on your previous code
top_hotels = df.nlargest(10, 'Starting_Rate($)')  # Change column name here
plt.figure(figsize=(10, 6))
# Assign the return value of sns.barplot to ax
ax = sns.barplot(x='Name', y='Starting_Rate($)', data=top_hotels, palette='viridis') # Change column name here
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Luxury Hotels by Starting Rate')
plt.ylabel('Starting Rate ($)')
plt.xlabel('Hotel Name')

# Add numerical data labels on top of bars as integers
for p in ax.patches:
    ax.annotate(int(p.get_height()),  # Convert to integer using int()
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha = 'center', va = 'center',
                xytext = (0, 10),
                textcoords = 'offset points')

plt.show()
# Out:
# <ipython-input-40-f6c02ca8c2a1>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Name', y='Starting_Rate($)', data=top_hotels, palette='viridis') # Change column name here

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ... (your previous code for loading and exploring the data) ...

# Group by location to analyze average starting rates
# Assuming the column name is 'Location' (adjust if different)
location_group = df.groupby('Location')['Starting_Rate($)'].mean().sort_values(ascending=False)
print("\nAverage Starting Rates by Location:\n", location_group)

# Plotting the average starting rates by location
plt.figure(figsize=(12, 6))
# Use location_group.index for x-axis labels
sns.barplot(x=location_group.index, y=location_group.values, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.title('Average Starting Rates by Location of top 50 Luxury Hotels')
plt.ylabel('Average Starting Rate ($)')
plt.xlabel('Location')
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()
# Out:
# Average Starting Rates by Location:
#  Location
# Amalfi                  4000.000000
# Yaukuve Levu Island     3500.000000
# Paris                   3066.666667
# Maldives                2800.000000
# Kyoto                   2000.000000
# Tokyo                   1900.000000
# Kruger National Park    1900.000000
# Surfside                1800.000000
# St. Barths              1700.000000
# Antibes                 1650.000000
# Singapore               1450.000000
# New York                1407.500000
# Marrakech               1400.000000
# London                  1366.666667
# Riviera Nayarit         1300.000000
# Lake Como               1300.000000
# Lisciano Niccone        1300.000000
# Sumba Island            1300.000000
# Rajasthan               1200.000000
# Madrid                  1200.000000
# Zaghi                   1150.000000
# Tulum                   1100.000000
# Florence                1000.000000
# Riviera Maya            1000.000000
# Los Angeles              995.000000
# ...

# %%
# Dining and Drinking Analysis
dining_counts = df['Dining_Area'].value_counts()
drinking_counts = df['Drinking_Area'].value_counts()

# Plot Dining Areas
plt.figure(figsize=(12, 5))  # Increased figure width
sns.barplot(x=dining_counts.index, y=dining_counts.values, palette='viridis')
plt.title('Popular Dining Areas in Luxury Hotels')
plt.xlabel('Dining Area')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right', fontsize=8)  # Adjust fontsize if needed
plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# Plot Drinking Areas
plt.figure(figsize=(12, 5))  # Increased figure width
sns.barplot(x=drinking_counts.index, y=drinking_counts.values, palette='plasma')
plt.title('Popular Drinking Areas in Luxury Hotels')
plt.xlabel('Drinking Area')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right', fontsize=8) # Adjust fontsize if needed
plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()
# Out:
# <ipython-input-26-51c5de012f9c>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dining_counts.index, y=dining_counts.values, palette='viridis')
# <ipython-input-26-51c5de012f9c>:12: UserWarning: Glyph 146 (\x92) missing from font(s) DejaVu Sans.
#   plt.tight_layout()  # Adjust layout to prevent overlapping
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 146 (\x92) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-26-51c5de012f9c>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=drinking_counts.index, y=drinking_counts.values, palette='plasma')
# ...

# %%
from wordcloud import WordCloud

# Generate Word Cloud for Overviews
text = " ".join(df['Overview'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(text)

# Display Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Key Themes in Top 50 Luxury Hotel Overviews', fontsize=16)
plt.show()

# %%
# Pet-Friendly and Family-Friendly Hotels
pet_friendly = df[df['Hotel_Ammenties'].str.contains('pet friendly', case=False, na=False)]
family_friendly = df[df['Hotel_Ammenties'].str.contains('family friendly', case=False, na=False)]

# Compare Starting Rates for Segments
segments = ['Pet Friendly', 'Family Friendly']
avg_rates = [pet_friendly['Starting_Rate($)'].mean(), family_friendly['Starting_Rate($)'].mean()]

# Plot Comparison
plt.figure(figsize=(8, 5))
ax = sns.barplot(x=segments, y=avg_rates, palette='Set2')  # Assign to ax here
plt.title('Average Starting Rates by Luxury Hotel Segment')
plt.ylabel('Average Starting Rate ($)')

# Add numerical data labels on top of bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',  # Format to 2 decimal places
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 10),
                textcoords='offset points')

plt.show()
# Out:
# <ipython-input-43-fac9c87eb0c2>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=segments, y=avg_rates, palette='Set2')  # Assign to ax here

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for pet-friendly hotels
pet_friendly_hotels = df[df['Hotel_Ammenties'].str.contains('pet friendly', case=False, na=False)]

# Count the number of pet-friendly hotels
num_pet_friendly = len(pet_friendly_hotels)

# Create a bar plot
plt.figure(figsize=(6, 4))
ax = sns.barplot(x=['Pet-Friendly Hotels'], y=[num_pet_friendly], palette='Set2')
plt.title('Number of Pet-Friendly Luxury Hotels')
plt.ylabel('Count')

# Add numerical label below the bar with adjusted position
ax.annotate(f'{num_pet_friendly}',
            (0, num_pet_friendly),  # Position of the label
            ha='center', va='center',
            xytext=(0, -15),  # Negative vertical offset
            textcoords='offset points')

plt.show()
# Out:
# <ipython-input-44-0d93e716785b>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=['Pet-Friendly Hotels'], y=[num_pet_friendly], palette='Set2')

# %%
# Step 1: Extract Country from Address
df['Country'] = df['Address'].apply(lambda x: x.split(',')[-1].strip())

# Step 2: Count Hotels per Country
country_counts = df['Country'].value_counts()

# Step 3: Plot Number of Hotels per Country
plt.figure(figsize=(10, 6))
sns.barplot(x=country_counts.index, y=country_counts.values, palette='viridis')
plt.title('Number of Luxury Hotels by Country in Top 50 List', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Number of Hotels', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-49-e641fe32e0c9>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_counts.index, y=country_counts.values, palette='viridis')

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Step 1: Combine relevant columns into a single feature
df['Features'] = df['Overview'] + " " + df['Dining_Area'] + " " + df['Drinking_Area'] + " " + df['Hotel_Ammenties']

# Step 2: Transform text data into TF-IDF features
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['Features'])

# Step 3: Compute cosine similarity between hotels
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Step 4: Define recommendation function
def recommend_hotel(hotel_name, cosine_sim=cosine_sim, df=df):
    if hotel_name not in df['Name'].values:
        return f"Hotel '{hotel_name}' not found in the dataset."

    # Find the index of the hotel
    idx = df[df['Name'] == hotel_name].index[0]

    # Get similarity scores and sort them
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get top 5 similar hotels (excluding the queried hotel itself)
    sim_scores = sim_scores[1:6]

    # Get hotel names
    recommended_hotels = [df['Name'].iloc[i[0]] for i in sim_scores]

    return recommended_hotels

# Step 5: Test the recommendation system
hotel_to_recommend = 'Capella Bangkok'
recommendations = recommend_hotel(hotel_to_recommend)
print(f"Hotels similar to '{hotel_to_recommend}':")
for rec in recommendations:
    print(f"- {rec}")
# Out:
# Hotels similar to 'Capella Bangkok':
# - Four Seasons Bangkok at Chao Phraya River
# - Raffles Singapore
# - Hotel Bel-Air
# - Cheval Blanc
# - One&Only Mandarina

# %%
# Define traveler personas
def identify_persona(amenities):
    if 'family friendly' in amenities:
        return 'Family Traveler'
    elif 'spa' in amenities:
        return 'Wellness Enthusiast'
    elif 'beach access' in amenities:
        return 'Beach Lover'
    else:
        return 'General Luxury Traveler'

# Apply persona identification
df['Traveler Persona'] = df['Hotel_Ammenties'].apply(identify_persona)

# Count by personas
persona_counts = df['Traveler Persona'].value_counts()

# Plot personas
plt.figure(figsize=(8, 5))
sns.barplot(x=persona_counts.index, y=persona_counts.values, palette='Set2')
plt.title('Luxury Traveler Personas', fontsize=16)
plt.xlabel('Persona')
plt.ylabel('Count of Hotels')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-53-e42bf467e70f>:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=persona_counts.index, y=persona_counts.values, palette='Set2')

# %%
# Extract countries from the Address
df['Country'] = df['Address'].apply(lambda x: x.split(',')[-1].strip())

# Count hotels by country
country_counts = df['Country'].value_counts()

# Create a heatmap-ready DataFrame
heatmap_data = pd.DataFrame({'Country': country_counts.index, 'Hotel Count': country_counts.values})

# Heatmap visualization
plt.figure(figsize=(10, 6))
sns.heatmap(
    heatmap_data.pivot_table(values='Hotel Count', index='Country', aggfunc='sum'),
    annot=True, fmt='d', cmap='viridis', cbar=True
)
plt.title('Heatmap of Luxury Hotel Counts by Country in Top 50 List', fontsize=16)
plt.xlabel('Country')
plt.ylabel('Luxury Hotel Count')
plt.show()

# %%
# Group data by country and calculate average starting rates
country_avg_rate = df.groupby('Country')['Starting_Rate($)'].mean().reset_index()

# Rename columns for clarity
country_avg_rate.columns = ['Country', 'Average Rate']

# Create a bar heatmap
plt.figure(figsize=(10, 6))
sns.barplot(
    x='Country', y='Average Rate', data=country_avg_rate, palette='coolwarm'
)
plt.title('Average Starting Rates of Luxury Hotels by Country in Top 50 List', fontsize=16)
plt.xlabel('Country')
plt.ylabel('Average Rate ($)')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-57-0d7aa442c039>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Plot: Name vs. Total Rooms
plt.figure(figsize=(10, 6))
sns.barplot(x='Name', y='Total_Rooms', data=df, palette='viridis')
plt.title('Luxury Hotel Name vs. Total Rooms in Top 50 List', fontsize=16)
plt.xlabel('Hotel Name', fontsize=14)
plt.ylabel('Total Rooms', fontsize=14)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()
# Out:
# <ipython-input-60-daf5335d5f70>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Name', y='Total_Rooms', data=df, palette='viridis')
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 150 (\x96) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Sort hotels by Total_Rooms in descending order and select the top 10
top_10_hotels_by_rooms = df.sort_values(by=['Total_Rooms'], ascending=False).head(10)

# Create the bar plot
plt.figure(figsize=(12, 6))  # Adjust figure size as needed
sns.barplot(x='Name', y='Total_Rooms', data=top_10_hotels_by_rooms, palette='viridis')
plt.title('Top 10 Luxury Hotels with the Most Rooms', fontsize=16)
plt.xlabel('Hotel Name', fontsize=14)
plt.ylabel('Total Rooms', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=10)  # Rotate x-axis labels
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()
# Out:
# <ipython-input-62-f634df56d86f>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Name', y='Total_Rooms', data=top_10_hotels_by_rooms, palette='viridis')

# %%
from sklearn.preprocessing import MinMaxScaler

# Compute rarity scores for Dining, Drinking, and Amenities
df['dining_rarity'] = df['Dining_Area'].map(df['Dining_Area'].value_counts(normalize=True))
df['drinking_rarity'] = df['Drinking_Area'].map(df['Drinking_Area'].value_counts(normalize=True))
df['amenities_rarity'] = df['Hotel_Ammenties'].map(df['Hotel_Ammenties'].value_counts(normalize=True))

# Calculate Uniqueness Index (inverse of commonality)
df['uniqueness_index'] = 1 - ((df['dining_rarity'] + df['drinking_rarity'] + df['amenities_rarity']) / 3)

# Normalize the index for better interpretation
scaler = MinMaxScaler()
df['uniqueness_index_normalized'] = scaler.fit_transform(df[['uniqueness_index']])

# Sort by uniqueness
unique_hotels = df.sort_values(by='uniqueness_index_normalized', ascending=False)
print(unique_hotels[['Name', 'uniqueness_index_normalized']])
# Out:
#                                          Name  uniqueness_index_normalized
# 25                                   The Siam                     1.000000
# 18                       Four Seasons Firenze                     1.000000
# 20                           Desa Potato Head                     1.000000
# 21                              Bulgari Tokyo                     1.000000
# 27                               Mount Nelson                     1.000000
# 29                                The Carlyle                     1.000000
# 30                                La Mamounia                     1.000000
# 31                        Four Seasons Madrid                     1.000000
# 33              Four Seasons at The Surf Club                     1.000000
# 34                              Hotel Bel-Air                     1.000000
# 35                                  Eden Rock                     1.000000
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ... (Your previous code to load and prepare the DataFrame 'df') ...

# Compute rarity scores for Dining, Drinking, and Amenities
df['dining_rarity'] = df['Dining_Area'].map(df['Dining_Area'].value_counts(normalize=True))
df['drinking_rarity'] = df['Drinking_Area'].map(df['Drinking_Area'].value_counts(normalize=True))
df['amenities_rarity'] = df['Hotel_Ammenties'].map(df['Hotel_Ammenties'].value_counts(normalize=True))

# Calculate Uniqueness Index (inverse of commonality)
df['uniqueness_index'] = 1 - ((df['dining_rarity'] + df['drinking_rarity'] + df['amenities_rarity']) / 3)

# Normalize the index for better interpretation
scaler = MinMaxScaler()
df['uniqueness_index_normalized'] = scaler.fit_transform(df[['uniqueness_index']])

# Sort by uniqueness and select top 10
unique_hotels = df.sort_values(by='uniqueness_index_normalized', ascending=False).head(10)

# Create the bar plot for top 10 unique hotels
plt.figure(figsize=(12, 6))
sns.barplot(x='Name', y='uniqueness_index_normalized', data=unique_hotels, palette='viridis')
plt.title('Top 10 Unique Luxury Hotels', fontsize=16)
plt.xlabel('Hotel Name', fontsize=14)
plt.ylabel('Uniqueness Index (Normalized)', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-65-53d9709395d6>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Name', y='uniqueness_index_normalized', data=unique_hotels, palette='viridis')

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans

# Vectorize the Hotel Amenities
vectorizer = CountVectorizer(stop_words='english')
amenities_matrix = vectorizer.fit_transform(df['Hotel_Ammenties'])

# Perform K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42)  # Adjust clusters as needed
df['cluster'] = kmeans.fit_predict(amenities_matrix)

# Analyze Clusters
print(df.groupby('cluster')['Hotel_Ammenties'].apply(lambda x: ' | '.join(x[:5])))
# Out:
# cluster
# 0     Swimming pool(s), spa/wellness centre, fitnes...
# 1    Unknown |  Beach, Pool |  Fitness centre, Wine...
# 2     Over 90 swimming pools, Skyblaze fountain, wa...
# Name: Hotel_Ammenties, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ... (Your previous code for data loading and preparation) ...

# Vectorize the Hotel Amenities
vectorizer = CountVectorizer(stop_words='english')
amenities_matrix = vectorizer.fit_transform(df['Hotel_Ammenties'])

# Perform K-Means Clustering
kmeans = KMeans(n_clusters=3, random_state=42)  # Adjust clusters as needed
df['cluster'] = kmeans.fit_predict(amenities_matrix)

# Analyze Clusters (print cluster characteristics)
print(df.groupby('cluster')['Hotel_Ammenties'].apply(lambda x: ' | '.join(x[:5])))

# Visualize Clusters (using PCA for dimensionality reduction)
from sklearn.decomposition import PCA

pca = PCA(n_components=2)  # Reduce to 2 dimensions for plotting
principal_components = pca.fit_transform(amenities_matrix.toarray())
principal_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])
principal_df['cluster'] = df['cluster']

plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', hue='cluster', data=principal_df, palette='viridis', s=100)
plt.title('Visualization of Hotel Clusters based on Amenities')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
# Out:
# cluster
# 0     Swimming pool(s), spa/wellness centre, fitnes...
# 1    Unknown |  Beach, Pool |  Fitness centre, Wine...
# 2     Over 90 swimming pools, Skyblaze fountain, wa...
# Name: Hotel_Ammenties, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ... (Your previous code to load, prepare, and calculate 'amenity_count' in 'df') ...

# Top Hotels with Most Amenities
top_amenity_hotels = df.nlargest(5, 'amenity_count')
print(top_amenity_hotels[['Name', 'amenity_count']])

# Create a bar plot for top hotels with most amenities
plt.figure(figsize=(10, 6))
sns.barplot(x='Name', y='amenity_count', data=top_amenity_hotels, palette='viridis')
plt.title('Top 5 Luxury Hotels with the Most Amenities', fontsize=16)
plt.xlabel('Hotel Name', fontsize=14)
plt.ylabel('Number of Amenities', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
#                                          Name  amenity_count
# 34                              Hotel Bel-Air              9
# 8                          Atlantis The Royal              8
# 13  Four Seasons Bangkok at Chao Phraya River              8
# 20                           Desa Potato Head              8
# 30                                La Mamounia              8
# <ipython-input-71-e557196dd0df>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Name', y='amenity_count', data=top_amenity_hotels, palette='viridis')
